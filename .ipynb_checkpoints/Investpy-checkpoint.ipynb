# %% [markdown]
# # Import library

# %%
import pandas as pd
import investpy as ip
import requests

# %% [markdown]
# # Test functions

# %% [markdown]
# ### Fund Information

# %%
data = ip.funds.get_fund_information(fund='one ultimate global growth fund', country='thailand', as_json=False)

# %%
data
# Out:
#                          Fund Name Rating 1-Year Change  Previous Close  \
# 0  one ultimate global growth fund             - 36.25%             NaN
#
#   Risk Rating TTM Yield     ROE  Issuer Turnover    ROA Inception Date  \
# 0                    0%  17.42%     NaN  237.92%  9.77%     04/02/2016
#
#    Total Assets Expenses  Min Investment    Market Cap       Category
# 0  8.340000e+09    2.30%             NaN  5.007060e+12  Global Equity

# %% [markdown]
# ### Fund history

# %%
hist_data = ip.funds.get_fund_historical_data(fund='one ultimate global growth fund', 
                                         country='thailand', 
                                         as_json=False, 
                                         from_date = '20/4/2022', 
                                         to_date = '21/4/2022',  
                                         order='ascending',
                                        interval = 'Daily')

# %%
hist_data
# Out:
#               Open    High     Low   Close Currency
# Date
# 2022-04-20  26.426  26.426  26.426  26.426      THB
# 2022-04-21  25.641  25.641  25.641  25.641      THB

# %% [markdown]
# ### Recent data

# %%
recent_data = ip.funds.get_fund_recent_data(fund='one ultimate global growth fund', 
                                         country='thailand', 
                                         as_json=False,  
                                         order='descending',
                                        interval = 'Daily')

# %%
recent_data
# Out:
#               Open    High     Low   Close Currency
# Date
# 2022-04-25  23.694  23.694  23.694  23.694      THB
# 2022-04-22  24.735  24.735  24.735  24.735      THB
# 2022-04-21  25.641  25.641  25.641  25.641      THB
# 2022-04-20  26.426  26.426  26.426  26.426      THB
# 2022-04-19  25.941  25.941  25.941  25.941      THB
# 2022-04-18  27.220  27.220  27.220  27.220      THB
# 2022-04-12  26.712  26.712  26.712  26.712      THB
# 2022-04-11  27.004  27.004  27.004  27.004      THB
# 2022-04-08  27.778  27.778  27.778  27.778      THB
# 2022-04-07  27.828  27.828  27.828  27.828      THB
# 2022-04-05  29.871  29.871  29.871  29.871      THB
# 2022-04-04  29.071  29.071  29.071  29.071      THB
# 2022-04-01  28.513  28.513  28.513  28.513      THB
# 2022-03-31  29.167  29.167  29.167  29.167      THB
# 2022-03-30  29.718  29.718  29.718  29.718      THB
# 2022-03-29  29.096  29.096  29.096  29.096      THB
# 2022-03-28  28.295  28.295  28.295  28.295      THB

# %% [markdown]
# ### Fund Overview

# %%
over_data = ip.funds.get_funds_overview(country = 'thailand', as_json=False, n_results=1000)

# %%
over_data
# Out:
#      country                                             name  \
# 0   thailand  Scb Short Term Fixed Income Plus Fund (class A)
# 1   thailand            Bualuang Thanatavee Fixed Income Fund
# 2   thailand   Digital Telecommunications Infrastructure Fund
# 3   thailand                           K Cash Management Fund
# 4   thailand   Jasmine Broadband Internet Infrastructure Fund
# ..       ...                                              ...
# 95  thailand      Value Plus - Dividend Long Term Equity Fund
# 96  thailand                     Thanachart Money Market Fund
# 97  thailand                      Principal Fixed Income Fund
# 98  thailand                           K Usa Equity Fund-a(a)
# 99  thailand                        Future Park Property Fund
#
#                                           full_name                 symbol  \
# 0   SCB Short Term Fixed Income Plus Fund (CLASS A)           SCBSFFPLUS-A
# 1             Bualuang Thanatavee Fixed Income Fund                 B-TNTV
# 2    Digital Telecommunications Infrastructure Fund                    DIF
# 3                            K Cash Management Fund                 K-CASH
# 4    JASMINE BROADBAND INTERNET INFRASTRUCTURE FUND                  JASIF
# ..                                              ...                    ...
# 95      Value Plus - Dividend Long Term Equity Fund             VALUE-DLTF
# 96                     Thanachart Money Market Fund                T-MONEY
# 97             CIMB-PRINCIPAL FAM Fixed Income Fund  CIMB-PRINCIPAL(FAM)FI
# 98                           K USA Equity Fund-A(A)             0P0001IGST
# 99                        Future Park Property Fund               FUTUREPF
#
#       last  change  total_assets currency
# 0   11.229      0%  157000000000      THB
# 1   13.399      0%  105040000000      THB
# 2   14.100  -0.70%  174950000000      THB
# 3   13.261      0%   80650000000      THB
# 4   10.800  -0.92%   61200000000      THB
# ..     ...     ...           ...      ...
# 95  25.197  +0.11%    5310000000      THB
# 96  12.128      0%    4910000000      THB
# 97  14.374      0%    5290000000      THB
# 98  15.787  -2.97%     169200000      THB
# 99  14.300   0.00%    5980000000      THB
#
# [100 rows x 8 columns]

# %% [markdown]
# ### Search

# %%
fund_name = ip.funds.search_funds(by = 'country', value = 'thailand')

# %%
fund_name
# Out:
#       country                                            name  \
# 0    thailand                  Principal Global Equity Fund A
# 1    thailand                            K Global Equity Fund
# 2    thailand              Phatra Global New Perspective Fund
# 3    thailand                           Mfc Global Smart Fund
# 4    thailand                  Tmb Global Quality Growth Fund
# ..        ...                                             ...
# 789  thailand                     Krungsri Dividend Stock Ltf
# 790  thailand          Bualuang Long - Term Equity Fund 75/25
# 791  thailand  Scb Dividend Stock 70/30 Long Term Equity Fund
# 792  thailand                              K Equity 70:30 Ltf
# 793  thailand                                       Bric Fund
#
#                      symbol                                    issuer  \
# 0    CIMB-PRINCIPAL(FAM)GEF  CIMB-Principal Asset Management Co., Ltd
# 1                   K-GLOBE         Kasikorn Asset Management Co. Ltd
# 2                 PHATRAGNP         Phatra Asset Management Co., Ltd.
# 3                       MGS                  MFC Asset Management PLC
# 4                    TMBGQG              TMB Asset Management Co. Ltd
# ..                      ...                                       ...
# 789                KFLTFDIV       Krungsri Asset Management Co., Ltd.
# 790                  BLTF75            BBL Asset Management Co., Ltd.
# 791                  SCBLT1            SCB Asset Management Co., Ltd.
# 792                  K70LTF         Kasikorn Asset Management Co. Ltd
# 793                    BRIC  UOB Asset Management (Thailand) Co., Ltd
#
#              isin asset_class currency underlying
# 0    TH5405010007      equity      THB
# 1    TH1648010003      equity      THB
# 2    TH6940010007      equity      THB
# 3    TH1327010001      equity      THB
# 4    TH6351010009      equity      THB
# ..            ...         ...      ...        ...
# 789  TH2525010009      equity      THB
# 790  TH1579010006      equity      THB
# 791  TH2564010001      equity      THB
# 792  TH2983010004      equity      THB
# 793  TH2238010007      equity      THB
#
# [794 rows x 8 columns]

# %% [markdown]
# ### Fund list

# %%
funds_list = ip.funds.get_funds_list(country = 'thailand')

# %%
len(funds_list)
print(funds_list)
# Out:
# ['Principal Global Equity Fund A', 'K Global Equity Fund', 'Phatra Global New Perspective Fund', 'Mfc Global Smart Fund', 'Tmb Global Quality Growth Fund', 'Asset Plus Global Allocation Fund', 'Scb Global Wealth Plus Open End Fund', 'One Ultimate Global Growth Fund', 'Bualuang Global Equity Fund', 'Tisco Global Stars Plus Fund', 'Scb Global Equity Fund (dividend)', 'Tmb Global Quality Growth Retirement Mutual Fund', 'Tmb World Equity Index Fund', 'Mfc Global Equity Fund', 'United Global Durable Equities Fund', 'Thanachart Global Equity Fund', 'Cimb-principal Global Silver Age Fund', 'Krungsri Global Brands Equity Rmf', 'Tisco Global Stars Plus Fund - Unhedged', 'Aberdeen Standard World Opportunities Fund', 'Bualuang Global Equity Rmf', 'Uob Smart Asia Active Allocation Fund', 'Krung Thai Opportunity Fund-a', 'Scb Global Wealth Open End Fund', 'Mfc International Fifteen Fund', 'Scb Platinum Global Open End Fund', 'Mfc International Ten Fund', 'K Strategic Global Multi-asset Fund', 'K Global Income Fund-a(r)', 'Scb Asia Pacific Income Plus Fund(not For Retail Investors)', 'Scb Global Income Plus Fund', 'United Platinum Income Opportunities Plus Fund', 'Krungsri Collective Global Income Fund', 'K Global Allocation Rmf', 'United Income Focus Fund-a', 'United Income Focus Fund-n', 'Uob Smart Asia Pacific Income Fund', 'Thanachart Global Income Property Fund Fund Not For Retail Investors', 'Krung Thai Opportunity Fund-d', 'United Income Focus Fund Rmf', 'Asset Plus Strategic Investment Fund', '1 A.m. Us Recovery Opportunity Fund', 'United Asia Pacific Income Fund', 'Scb Global Wealth Plus Rmf', 'Thanachart Multi Asset Portfolio', 'Scb Global Wealth Rmf', 'Krungsri Global Small-mid Cap Equity Dividend Fund', 'Tisco Global Healthcare Rmf', 'Thanachart Global Value Fund', 'Scb Global Infrastructure Rmf', 'K India Equity Fund', 'Aberdeen Standard India Growth Fund', 'K Indian Equity Index Fund', 'Tisco India Equity Fund', 'Ktam India Equity Fund-a', 'Ktam India Equity Fund-d', 'Uob Smart Japan Small And Mid Cap Fund', 'K Japan Equity Fund', 'Krungsri Japan Hedged Dividend Fund', 'Japan Small And Mid Cap Fund', 'Tmb Japan Active Equity Fund', 'Lh Japan - E Fund', 'Tisco Japan Equity Fund', 'Aberdeen Standard Japan Opportunities Fund', 'Asset Plus Nippon Growth Fund', 'Thanachart Japan Equity Fund', 'Krungsri Japan Rmf', 'Scb Japan Equity Rmf', 'Tisco Japan Equity Rmf', 'Scb Japan Equity Fund Dividend', 'Scb Global Infrastructure Equity Fund', 'Thanachart Premium Brands Fund', 'Cimb-principal Global Infrastructure Equity Fund', 'Thanachart Global Healthcare Retirement Mutual Fund', 'Mfc International Develop Markets Fund', 'Thanachart Global Equity Retirement Mutual Fund', 'Krungsri Global High Payout Fund', 'United Global Security Equities Fund', 'One Global Equity Fund', 'Mfc Global Alpha Fund', 'Bualuang Global Health Care Fund', 'Uob Smart Global Healthcare Fund', 'Scb Global Health Care Equity Fund', 'K Global Healthcare Equity Rmf', 'Thanachart Global Healthcare Fund', 'United Global Healthcare Fund', 'Tisco Global Healthcare Stars Plus Fund', 'K Global Healthcare Equity Unhedged Fund', 'Ktam World Healthcare Fund A', 'United Global Healthcare Rmf', 'Phatra Global Health Care Fund', 'Manulife Strength - Healthcare Fif-a', 'Manulife Strength - Healthcare Fif-d', 'Scb Global Health Care Rmf', 'Ktam World Healthcare Rmf', 'Mfc Smart Innovation Series 1 Fund', 'Mfc Smart Investment Series 5 E3 Fund', 'Krungsri Europe Equity Hedged Fund', 'Mfc International Twenty Fund', 'Asset Plus Growth Dividend Fund', 'Mfc Active Equity Fund', 'Theerasub Open-end Fund', 'One Shariah Long Term Equity Fund', 'Principal Set100 Retirement Mutual Fund', 'Phillip Equity Fund', 'Sinchada Open-end Fund', 'Lh Growth Fund-r', '1 A.m. Set 50 Fund Ra', 'Bualuang Basic Dividend Ltf', 'Bualuang Siriphol Corporate Governance', 'K Mid Small Cap Equity Rmf', 'Bualuang Siriphol Corporate Governance Rmf', 'Bualuang Basic Rmf', 'Thanachart Prime Low Beta Fund', 'Tisco M ...

# %% [markdown]
# ### Retrieve data

# %%
my_fundlist = ['KFSDIV','KFSEQ-D','KF-LTFDIV','KFGBRAND','KFGDIV','KFGG','K-CASH','K-INDIA','K-US500X','K-USXNDQ']

# %%
fund_name = ip.funds.search_funds(by = 'country', value = 'thailand')

# %%
fund_name[fund_name['symbol'].isin(my_fundlist)]
# Out:
#       country                                name   symbol  \
# 50   thailand                 K India Equity Fund  K-INDIA
# 515  thailand              K Cash Management Fund   K-CASH
# 621  thailand  Krungsri Star Equity Dividend Fund  KFSEQ-D
# 771  thailand        Krungsri Dividend Stock Fund   KFSDIV
#
#                                   issuer          isin asset_class currency  \
# 50     Kasikorn Asset Management Co. Ltd  TH1286010000      equity      THB
# 515    Kasikorn Asset Management Co. Ltd  TH2733010007        bond      THB
# 621  Krungsri Asset Management Co., Ltd.  TH1166010005      equity      THB
# 771  Krungsri Asset Management Co., Ltd.  TH1366010003      equity      THB
#
#     underlying
# 50
# 515
# 621
# 771

# %%
my_funds = list(fund_name[fund_name['symbol'].isin(my_fundlist)]['name'])

# %%
my_funds
# Out:
# ['K India Equity Fund',
#  'K Cash Management Fund',
#  'Krungsri Star Equity Dividend Fund',
#  'Krungsri Dividend Stock Fund']

# %%
data = ip.funds.get_fund_information(fund=my_funds[0], country='thailand', as_json=False)

# %%
data = data[['Fund Name','1-Year Change','Category']]

# %%
data
# Out:
#              Fund Name 1-Year Change      Category
# 0  k india equity fund         4.93%  India Equity

# %%
 hist_data = ip.funds.get_fund_historical_data(fund=my_funds[0], 
                                         country='thailand', 
                                         as_json=False, 
                                         from_date = '20/4/2022', 
                                         to_date = '21/4/2022',  
                                         order='ascending',
                                         interval = 'Daily')

# %%
hist_data.reset_index(inplace = True)

# %%
hist_data.rename(columns = {'Date':'Buy Date', 'Close':'Buying Price'}, inplace = True)

# %%
hist = hist_data[['Buy Date', 'Buying Price']].iloc[[0]]

# %%
recent_data = ip.funds.get_fund_recent_data(fund=my_funds[0], 
                                         country='thailand', 
                                         as_json=False,  
                                         order='descending',
                                        interval = 'Daily')

# %%
recent_data.reset_index(inplace = True)

# %%
recent_data.rename(columns = {'Date':'Latest Date', 'Close':'Latest Price'}, inplace = True)

# %%
recent = recent_data[['Latest Date','Latest Price']].iloc[[0]]

# %%
df = data.join([hist, recent])

# %%
df
# Out:
#              Fund Name 1-Year Change      Category   Buy Date  Buying Price  \
# 0  k india equity fund         4.93%  India Equity 2022-04-20        11.357
#
#   Latest Date  Latest Price
# 0  2022-04-25        11.193

# %%
fund_name = ip.funds.search_funds(by = 'country', value = 'thailand')

# %%
fund_name = fund_name[fund_name['name'] == my_funds[0]]

# %%
fund_name.reset_index(inplace = True)

# %%
fund_name = fund_name[['symbol']]

# %%
fund_name
# Out:
#     symbol
# 0  K-INDIA

# %%
df = data.join([hist, recent, fund_name])

# %%
df
# Out:
#              Fund Name 1-Year Change      Category   Buy Date  Buying Price  \
# 0  k india equity fund         4.93%  India Equity 2022-04-20        11.357
#
#   Latest Date  Latest Price   symbol
# 0  2022-04-25        11.193  K-INDIA

# %%
def get_funds(my_funds):
    data = ip.funds.get_fund_information(fund=my_funds, country='thailand', as_json=False)
    data = data[['Fund Name','1-Year Change','Category']]
    
    hist_data = ip.funds.get_fund_historical_data(fund=my_funds, 
                                         country='thailand', 
                                         as_json=False, 
                                         from_date = '20/4/2022', 
                                         to_date = '21/4/2022',  
                                         order='ascending',
                                         interval = 'Daily')
    hist_data.reset_index(inplace = True)
    hist_data.rename(columns = {'Date':'Buy Date', 'Close':'Buying Price'}, inplace = True)
    hist = hist_data[['Buy Date', 'Buying Price']].iloc[[0]]
    
    recent_data = ip.funds.get_fund_recent_data(fund=my_funds, 
                                         country='thailand', 
                                         as_json=False,  
                                         order='descending',
                                        interval = 'Daily')
    recent_data.reset_index(inplace = True)
    recent_data.rename(columns = {'Date':'Latest Date', 'Close':'Latest Price'}, inplace = True)
    recent = recent_data[['Latest Date','Latest Price']].iloc[[0]]
    
    fund_name = ip.funds.search_funds(by = 'country', value = 'thailand')
    fund_name = fund_name[fund_name['name'] == my_funds]
    fund_name.reset_index(inplace = True)
    fund_name = fund_name[['symbol']]
    
    df = data.join([hist, recent, fund_name])
    return df

# %%
thai_fund = pd.DataFrame(columns=['Fund Name','1-Year Change', 'Category','Buy Date', 'Buying Price','Latest Date', 'Latest Price','symbol'])

def get_df():
   global thai_fund
   for i in range(len(my_funds)):
     fund_data = get_funds(my_funds[i])
    
    
     thai_fund = pd.concat([thai_fund, fund_data])
   return thai_fund

# %%
result = get_df()

# %%
result
# Out:
#                              Fund Name 1-Year Change            Category  \
# 0                  k india equity fund         5.06%        India Equity
# 0  k us equity ndq 100 index fund-a(d)      - 10.94%           US Equity
# 0               k cash management fund         0.28%                 NaN
# 0   krungsri star equity dividend fund       - 9.21%  Equity Large - Cap
# 0         krungsri dividend stock fund       - 2.03%  Equity Large - Cap
# 0          krungsri dividend stock ltf         0.55%  Equity Large - Cap
#
#     Buy Date  Buying Price Latest Date  Latest Price         symbol
# 0 2022-04-20        11.357  2022-04-26        11.326        K-INDIA
# 0 2022-04-20        22.208  2022-04-26        20.653  K-USXNDQ-A(D)
# 0 2022-04-20        13.260  2022-04-27        13.261         K-CASH
# 0 2022-04-20         5.668  2022-04-27         5.600        KFSEQ-D
# 0 2022-04-20         6.893  2022-04-27         6.830         KFSDIV
# 0 2022-04-20        20.840  2022-04-27        20.620       KFLTFDIV

# %%
def linemsg(df): 
    string = ''
    for i in range(len(df)):
        var0 = f"{df.iloc[i]['symbol']} Latest Price = {df.iloc[i]['Latest Price']}, YOY {df.iloc[i]['1-Year Change']}"
        string = '\n'.join([string,var0])
    return string

# %%
test = linemsg(result)
print(test)
# Out:
# K-INDIA Latest Price = 11.326, YOY 5.06%
# K-USXNDQ-A(D) Latest Price = 20.653, YOY - 10.94%
# K-CASH Latest Price = 13.261, YOY 0.28%
# KFSEQ-D Latest Price = 5.6, YOY - 9.21%
# KFSDIV Latest Price = 6.83, YOY - 2.03%
# KFLTFDIV Latest Price = 20.62, YOY 0.55%

# %% [markdown]
# ## Notification

# %%
url = 'https://notify-api.line.me/api/notify'
token = 'F9jkt2fViXeftUZZ176vrLMnwc5kpmTo2mkmiAo7Fr8'
headers = {'content-type':'application/x-www-form-urlencoded','Authorization':'Bearer '+token}

msg = linemsg(result)

r = requests.post(url, headers=headers, data = {'message':msg})
print (r.text)
# Out:
# {"status":200,"message":"ok"}

# %% [markdown]
# # Line OA

# %%
from flask import Flask, request, abort
from settrade.openapi import Investor
from linebot import (LineBotApi, WebhookHandler)
from linebot.exceptions import (InvalidSignatureError)
from linebot.models import (MessageEvent, PostbackEvent, TextMessage, TextSendMessage,
                            FlexSendMessage, QuickReply, QuickReplyButton, MessageAction,
                            PostbackAction)

# %%
app = Flask(__name__)

# %%
lineaccesstoken = 'aAUcds3sF1PhpOtfVUrFo182AE0BKu4sWJ/UJXplOkCCyoGdRUQmvZSgdKIOXUnJ9JlQsp9cemuT/jKYmurgRmuidyznwI5YQ3BZa5vWRjfhnD3CVHPXo7lL1uQd3v8Vd8qsDEiwRVUc7INxrMruWgdB04t89/1O/w1cDnyilFU='
line_bot_api = LineBotApi(lineaccesstoken)
handler = WebhookHandler('c10702d7cc6facabd2cc7be946f13f78')

investor = Investor(app_id="2MLsxfXVQlOdZMnR",
                    app_secret="AMIMWYD8oBdA8Na8bJjlE+o7HL8sz2czpZ9kNLfGKpyX",
                    broker_id = 'SANDBOX',
                    app_code = 'SANDBOX',
                    is_auto_queue = False)
equity = investor.Equity(account_no="guisilly-E")
realtime = investor.RealtimeDataConnection()

# %%
realtime

# %%
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        print("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'

# %%
def handle_message(event):
    text = event.message.text
    # user click rich menu
    if "My portfolio" in text:
        check_my_portfolio(event)
        
    # user send symbol to check the price before buy/sell
    else:
        sub = realtime.subscribe_price_info(
            event.message.text, on_message=price_info, args=(event,))
        sub.start()

# %%
def check_my_portfolio(event):
    portfolio = equity.get_portfolio()
    portfolio_datas = []

    # get data from each stock in portfolio
    for data in portfolio["data"]:
        # green color
        color_code = "#00df5b"
        if data["profit"] < 0:
            # red color, if the profit is minus
            color_code = "#ed1c24"

        content = {
            "type": "box",
            "layout": "vertical",
            "contents": [
                {
                    "type": "text",
                    "text": data["symbol"],
                    "size": "xxl",
                    "weight": "bold",
                    "color": "#ffffff"
                },
                {
                    "type": "text",
                    "text": str(data["profit"]) + " (" + str(data["percent_profit"]) + "%)",
                    "size": "xl",
                    "weight": "bold",
                    "color": color_code
                },
                {
                    "type": "text",
                    "text": "Actual Vol " + str(data["actual_volume"]),
                    "size": "xs",
                    "color": "#bababa"
                },
                {
                    "type": "text",
                    "text": "Amount " + str(data["amount"]),
                    "size": "xs",
                    "color": "#bababa"
                },
                {
                    "type": "text",
                    "text": "Avg Price " + str(data["average_price"]),
                    "size": "xs",
                    "color": "#bababa"
                },
                {
                    "type": "text",
                    "text": "Market Price " + str(data["market_price"]),
                    "size": "xs",
                    "color": "#bababa"
                },
                {
                    "type": "text",
                    "text": "Market Value " + str(data["market_value"]),
                    "size": "xs",
                    "color": "#bababa"
                }
            ],
            "paddingTop": "5px"
        }
        portfolio_datas.append(content)

    line_bot_api.reply_message(
        event.reply_token,
        FlexSendMessage(
            alt_text='My portfolio',
            contents={
                "type": "bubble",
                "size": "mega",
                "header": {
                    "type": "box",
                    "layout": "horizontal",
                    "contents": [],
                    "backgroundColor": "#37e165",
                    "height": "10px"
                },
                "body": {
                    "type": "box",
                    "layout": "vertical",
                    "contents": portfolio_datas,
                    "backgroundColor": "#0d0d0d"
                },
                "styles": {
                    "footer": {
                        "backgroundColor": "#0d0d0d"
                    }
                }
            }
        )
    )

# %%
def price_info(result, subscriber, event):
    high_price = result['data']['high']
    last_price = result['data']['last']
    low_price = result['data']['low']
    volume = result['data']['total_volume']
    symbol = event.message.text

    line_bot_api.reply_message(
        event.reply_token,
        FlexSendMessage(
            alt_text=symbol,
            contents={
                "type": "bubble",
                "size": "mega",
                "header": {
                    "type": "box",
                    "layout": "horizontal",
                    "contents": [],
                    "backgroundColor": "#37e165",
                    "height": "10px"
                },
                "body": {
                    "type": "box",
                    "layout": "vertical",
                    "contents": [
                        {
                            "type": "text",
                            "text": symbol,
                            "size": "xl",
                            "weight": "bold",
                            "color": "#a6a6a6"
                        },
                        {
                            "type": "text",
                            "text": str(last_price),
                            "size": "3xl",
                            "weight": "bold",
                            "color": "#ebebeb"
                        },
                        {
                            "type": "text",
                            "text": "High " + str(high_price),
                            "size": "xs",
                            "color": "#bababa"
                        },
                        {
                            "type": "text",
                            "text": "Low " + str(low_price),
                            "size": "xs",
                            "color": "#bababa"
                        },
                        {
                            "type": "text",
                            "text": "Volume " + str(volume),
                            "size": "xs",
                            "color": "#bababa"
                        },
                        {
                            "type": "separator",
                            "margin": "xl",
                            "color": "#bdbdbd"
                        }
                    ],
                    "paddingTop": "23px",
                    "backgroundColor": "#0d0d0d"
                },
                "footer": {
                    "type": "box",
                    "layout": "vertical",
                    "contents": [
                        {
                            "type": "box",
                            "layout": "horizontal",
                            "contents": [
                                {
                                    "type": "box",
                                    "layout": "horizontal",
                                    "contents": [
                                        {
                                            "type": "text",
                                            "text": "BUY",
                                            "size": "sm",
                                            "color": "#ffffff",
                                            "align": "center",
                                            "gravity": "center",
                                            "weight": "bold"
                                        }
                                    ],
                                    "height": "40px",
                                    "borderWidth": "medium",
                                    "borderColor": "#2edc39",
                                    "cornerRadius": "4px",
                                    "action": {
                                        "type": "postback",
                                        "label": "buy",
                                        "data": "symbol=" + symbol + "&side=buy&price=" + str(last_price)
                                    }
                                },
                                {
                                    "type": "box",
                                    "layout": "horizontal",
                                    "contents": [
                                        {
                                            "type": "text",
                                            "text": "SELL",
                                            "size": "sm",
                                            "color": "#ffffff",
                                            "align": "center",
                                            "gravity": "center",
                                            "weight": "bold"
                                        }
                                    ],
                                    "height": "40px",
                                    "borderWidth": "medium",
                                    "borderColor": "#dc2e39",
                                    "cornerRadius": "4px",
                                    "action": {
                                        "type": "postback",
                                        "label": "sell",
                                        "data": "symbol=" + symbol + "&side=sell&price=" + str(last_price)
                                    }
                                }
                            ],
                            "spacing": "md"
                        }
                    ],
                    "paddingAll": "13px"
                },
                "styles": {
                    "footer": {
                        "backgroundColor": "#0d0d0d"
                    }
                }
            }
        )
    )
    # stop this subscription
    subscriber.stop()

# %%
def handle_postback(event):
    postback_data = event.postback.data
    values = get_value_from_postback(postback_data)
    symbol = values[0]
    side = values[1]
    price = values[2]

    # case user confirm to buy/sell stock
    if "confirm=true" in postback_data:
        volume = values[3]
        place_order = equity.place_order(
            symbol=symbol,
            price=price,
            volume=volume,
            side=side,
            pin="your-pin")

    # case user click buy/sell after check the price
    elif "vol" not in postback_data:
        line_bot_api.reply_message(
            event.reply_token,
            TextSendMessage(text='Select the volume that you want to ' + side + ' ' + symbol + ' at price ' + price,
                            quick_reply=QuickReply(items=[
                                QuickReplyButton(action=PostbackAction(
                                    label='+100',
                                    display_text='+100',
                                    data=postback_data + '&vol=100'
                                )),
                                QuickReplyButton(action=PostbackAction(
                                    label='+300',
                                    display_text='+300',
                                    data=postback_data + '&vol=300'
                                )),
                                QuickReplyButton(action=PostbackAction(
                                    label='+500',
                                    display_text='+500',
                                    data=postback_data + '&vol=500'
                                )),
                                QuickReplyButton(action=PostbackAction(
                                    label='+700',
                                    display_text='+700',
                                    data=postback_data + '&vol=700'
                                )),
                                QuickReplyButton(action=PostbackAction(
                                    label='+1000',
                                    display_text='+1000',
                                    data=postback_data + '&vol=1000'
                                ))
                            ])))
    
    # case user already choose volume how much they want to buy/sell
    else:
        volume = values[3]
        line_bot_api.reply_message(
            event.reply_token,
            TextSendMessage(text='Confirm to ' + side + ' ' + symbol + ' at price ' + price + ' with volume ' + volume,
                            quick_reply=QuickReply(items=[
                                QuickReplyButton(action=PostbackAction(
                                    label='Confirm',
                                    display_text='Confirm to ' +
                                    side + ' ' + symbol + ' at price ' +
                                    price + ' with volume ' + volume,
                                    data=postback_data + '&confirm=true'
                                )),
                                QuickReplyButton(action=MessageAction(
                                    label='Cancel',
                                    text='Cancel'
                                ))
                            ])))

# %%
def get_value_from_postback(data):
    datas = data.split("&")
    values = []
    for word in datas:
        tmp_value = word.split("=")
        values.append(tmp_value[1])

    return values

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [28/Apr/2022 15:25:19] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 15:25:20] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 15:25:29] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [28/Apr/2022 15:25:52] "GET / HTTP/1.1" 404 -
